# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_dat = np.linspace(1,10)
y_dat = x_dat**2+x_dat

# %%
fig0 = plt.figure()
ax0 = fig0.add_subplot() # adding axis??
ax0.plot(x_dat, y_dat, "d-r", mfc="none")

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot() # adding axis??

y_dat = 2 * x_dat + 1

ax1.plot(x_dat, y_dat, "o-b", mfc="none")
